# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaibhavbhor404/workshops/blob/main/supervised_26_3_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv('green_tech_data.csv')
df.shape
# Out:
# (100, 5)

# %%
df.head()
# Out:
#    carbon_emissions  energy_output  ...  cost_efficiency  sustainability
# 0        181.089042     128.286267  ...         0.732568               1
# 1        382.750007     672.769370  ...         2.891096               0
# 2        306.197880     382.920383  ...         2.932858               0
# 3        259.530469     557.713622  ...         3.368435               0
# 4        104.606524     916.809827  ...         3.767411               0
#
# [5 rows x 5 columns]

# %%
df.tail()
# Out:
#     carbon_emissions  energy_output  ...  cost_efficiency  sustainability
# 95        222.828459     414.288617  ...         4.688408               0
# 96        232.956490     753.360111  ...         4.362857               0
# 97        199.639356     907.399234  ...         2.430473               0
# 98         58.896694     898.377782  ...         3.878920               0
# 99         87.761999     801.887991  ...         3.895443               0
#
# [5 rows x 5 columns]

# %%
df.describe()
# Out:
#        carbon_emissions  energy_output  ...  cost_efficiency  sustainability
# count        100.000000     100.000000  ...       100.000000       100.00000
# mean         214.563260     548.048551  ...         2.710170         0.15000
# std          104.121294     263.800127  ...         1.320535         0.35887
# min           51.932741     106.256917  ...         0.564771         0.00000
# 25%          117.620266     317.804074  ...         1.623267         0.00000
# 50%          212.449859     555.062371  ...         2.793732         0.00000
# 75%          305.571092     789.565238  ...         3.810999         0.00000
# max          395.410428     987.085409  ...         4.957273         1.00000
#
# [8 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# carbon_emissions      0
# energy_output         0
# renewability_index    0
# cost_efficiency       0
# sustainability        0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.fillna(df.mean(),inplace=True)

# %%
df.columns
# Out:
# Index(['carbon_emissions', 'energy_output', 'renewability_index',
#        'cost_efficiency', 'sustainability'],
#       dtype='object')

# %%
x=df[['carbon_emissions','energy_output','renewability_index', 'cost_efficiency']]
y=df['sustainability']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=model.predict(x_test)
accuracy=accuracy_score(y_test,y_pred)
print('Accuracy:',accuracy)
# Out:
# Accuracy: 0.95

# %%
conf_matrix=confusion_matrix(y_test,y_pred)
sns.heatmap(conf_matrix,annot=True,fmt='d',cmap='Reds',xticklabels=['Not Sustainable','Sustainable'],yticklabels=['Not Sustainable','Sustainable'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix:')
plt.show()

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

print(classification_report(y_test,y_pred,target_names=['Not Sustainable','Sustainable']))
# Out:
#                  precision    recall  f1-score   support
#
# Not Sustainable       0.94      1.00      0.97        17
#     Sustainable       1.00      0.67      0.80         3
#
#        accuracy                           0.95        20
#       macro avg       0.97      0.83      0.89        20
#    weighted avg       0.95      0.95      0.95        20

# %%
import joblib
joblib.dump(model,'Irmodel_sustainable.pkl')
# Out:
# ['Irmodel_sustainable.pkl']
